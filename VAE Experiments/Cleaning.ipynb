# %%
import pandas as pd

df = pd.read_csv('./trade.csv')
# Out:
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (3,5,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#        ORGANIZATION NUMBER                  ACCOUNT_NAME  PACKAGE_ID  \
# 0           FRESHPOINT_158          BRINKER-CHILI'S #075    36316567
# 1           FRESHPOINT_158          BRINKER-CHILI'S #075    36316567
# 2           FRESHPOINT_158          BRINKER-CHILI'S #075    36316567
# 3           FRESHPOINT_158          BRINKER-CHILI'S #075    36316567
# 4           FRESHPOINT_158          BRINKER-CHILI'S #075    36316567
# 5           FRESHPOINT_158          BRINKER-CHILI'S #075    36316567
# 6           FRESHPOINT_158          BRINKER-CHILI'S #075    36316567
# 7           FRESHPOINT_158          BRINKER-CHILI'S #075    36316567
# 8           FRESHPOINT_158          BRINKER-CHILI'S #075    36316567
# 9           FRESHPOINT_158          BRINKER-CHILI'S #075    36316567
# 10          FRESHPOINT_158          BRINKER-CHILI'S #075    36316567
# 11          FRESHPOINT_158          BRINKER-CHILI'S #075    36316567
# 12          FRESHPOINT_158          BRINKER-CHILI'S #075    36316567
# 13          FRESHPOINT_158          BRINKER-CHILI'S #075    36316567
# 14          FRESHPOINT_158          BRINKER-CHILI'S #075    36340569
# 15          FRESHPOINT_158          BRINKER-CHILI'S #075    36340569
# 16          FRESHPOINT_158          BRINKER-CHILI'S #075    36340569
# 17          FRESHPOINT_158          BRINKER-CHILI'S #075    36340569
# 18          FRESHPOINT_158          BRINKER-CHILI'S #075    36340569
# 19          FRESHPOINT_158          BRINKER-CHILI'S #075    36340569
# 20          FRESHPOINT_158          BRINKER-CHILI'S #075    36340569
# 21          FRESHPOINT_158          BRINKER-CHILI'S #075    36340569
# 22          FRESHPOINT_158          BRINKER-CHILI'S #075    36340569
# 23          FRESHPOINT_158          BRINKER-CHILI'S #075    36340569
# 24          FRESHPOINT_158          BRINKER-CHILI'S #075    36340569
# 25          FRESHPOINT_158          BRINKER-CHILI'S #075    36340569
# 26          FRESHPOINT_158          BRINKER-CHILI'S #075    36340569
# 27          FRESHPOINT_158          BRINKER-CHILI'S #075    36340569
# 28          FRESHPOINT_158          BRINKER-CHILI'S #075    36340569
# 29          FRESHPOINT_158          BRINKER-CHILI'S #075    36340569
# ...                    ...                           ...         ...
# 495952      FRESHPOINT_108         BRINKER CHILI'S #1309    44063577
# 495953      FRESHPOINT_108         BRINKER CHILI'S #1309    44063577
# 495954      FRESHPOINT_108         BRINKER CHILI'S #1309    44063577
# 495955      FRESHPOINT_108         BRINKER CHILI'S #1309    44063577
# 495956      FRESHPOINT_108         BRINKER CHILI'S #1309    44063577
# 495957      FRESHPOINT_108         BRINKER CHILI'S #1309    44063577
# 495958      FRESHPOINT_108         BRINKER CHILI'S #1309    44063577
# 495959      FRESHPOINT_108         BRINKER CHILI'S #1309    44063577
# 495960      FRESHPOINT_108         BRINKER CHILI'S #1309    44063577
# 495961      FRESHPOINT_108         BRINKER CHILI'S #1309    44063577
# 495962      FRESHPOINT_108         BRINKER CHILI'S #1309    44063577
# 495963      FRESHPOINT_108         BRINKER CHILI'S #1309    44084501
# 495964      FRESHPOINT_108         BRINKER CHILI'S #1309    44084501
# 495965      FRESHPOINT_108         BRINKER CHILI'S #1309    44084501
# 495966      FRESHPOINT_108         BRINKER CHILI'S #1309    44084501
# 495967      FRESHPOINT_108         BRINKER CHILI'S #1309    44084501
# 495968      FRESHPOINT_108         BRINKER CHILI'S #1309    44084501
# 495969      FRESHPOINT_108         BRINKER CHILI'S #1309    44084501
# 495970      FRESHPOINT_108         BRINKER CHILI'S #1309    44084501
# 495971      FRESHPOINT_108         BRINKER CHILI'S #1309    44084501
# 495972      FRESHPOINT_108         BRINKER CHILI'S #1309    44084501
# 495973      FRESHPOINT_108         BRINKER CHILI'S #1309    44084501
# 495974      FRESHPOINT_108         BRINKER CHILI'S #1309    44084501
# 495975      FRESHPOINT_108         BRINKER CHILI'S #1309    44084501
# 495976      FRESHPOINT_108         BRINKER CHILI'S #1309    44084501
# 495977      FRESHPOINT_108         BRINKER CHILI'S #1309    44084501
# 495978            SYSCO067     BRINKER INTERNATIONAL INC    43490087
# 495979           WASSER_49  BRINKER NEW CULINARY CENTER-    43789973
# 495980           WASSER_49  BRINKER NEW CULINARY CENTER-    43789973
# 495981      FRESHPOINT_108          BRINKER CHILI'S #455    43983340
#
#        INVOICE_NUM TRANSACTION_DATE DC_PROD_NUM  \
# 0          1845456        01-MAR-17      100047
# 1          1845456        01-MAR-17      101217
# 2          1845456        01-MAR-17      101575
# 3          1845456        01-MAR-17      101699
# 4          1845456        01-MAR-17      101216
# 5          1845456        01-MAR-17      100821
# 6          1845456        01-MAR-17      101320
# 7          1845456        01-MAR-17      101982
# 8          1845456        01-MAR-17      430070
# 9          1845456        01-MAR-17      100218
# 10         1845456        01-MAR-17      101617
# 11         1845456        01-MAR-17      850122
# 12         1845456        01-MAR-17      870024
# 13         1845456        01-MAR-17      100067
# 14         1846684        03-MAR-17      100067
# 15         1846684        03-MAR-17      100294
# 16         1846684        03-MAR-17      101216
# 17         1846684        03-MAR-17      101217
# 18         1846684        03-MAR-17      101306
# 19         1846684        03-MAR-17      101320
# 20         1846684        03-MAR-17      101575
# 21         1846684        03-MAR-17      101664
# 22         1846684        03-MAR-17      101699
# 23         1846684        03-MAR-17      101724
# 24         1846684        03-MAR-17      101786
# 25         1846684        03-MAR-17      101802
# 26         1846684        03-MAR-17      101982
# 27         1846684        03-MAR-17      430070
# 28         1846684        03-MAR-17      100218
# 29         1846684        03-MAR-17      100911
# ...            ...              ...         ...
# 495952     4124603        26-JAN-19      400108
# 495953     4124603        26-JAN-19      400030
# 495954     4124603        26-JAN-19      400270
# 495955     4124603        26-JAN-19      401131
# 495956     4124603        26-JAN-19      505002
# 495957     4124603        26-JAN-19      514034
# 495958     4124603        26-JAN-19      100511
# 495959     4124603        26-JAN-19      400853
# 495960     4124603        26-JAN-19      101304
# 495961     4124603        26-JAN-19      120306
# 495962     4124603        26-JAN-19      400461
# 495963     4125152        28-JAN-19      500405
# 495964     4125152        28-JAN-19      505001
# 495965     4125152        28-JAN-19      400530
# 495966     4125152        28-JAN-19      505003
# 495967     4125152        28-JAN-19      590192
# 495968     4125152        28-JAN-19      400621
# 495969     4125152        28-JAN-19      400650
# 495970     4125152        28-JAN-19      400270
# 495971     4125152        28-JAN-19      401062
# 495972     4125152        28-JAN-19      401131
# 495973     4125152        28-JAN-19      505002
# 495974     4125152        28-JAN-19      401194
# 495975     4125152        28-JAN-19      101304
# 495976     4125152        28-JAN-19      120306
# 495977     4125152        28-JAN-19      400569
# 495978   267780803        05-DEC-18     3831637
# 495979  9413312244        02-JAN-19      107547
# 495980  9413312244        02-JAN-19     FREIGHT
# 495981     4120812        18-JAN-19      400280
#
#                             DC_PROD_NAME DC_UNIT_OF_MEASURE DC_QTY  \
# 0                        ORANGES--88CT *                 CS      1
# 1                    SPRING MIX--4/3# BR                 CS      1
# 2              BROCCOLI--FLORETS 6/3# BR                 CS      1
# 3             ONION--YELLOW JUMBO 50# BR                 CS      1
# 4         LETTUCE--ICEBERG CHPD 1X1 8/2#                 CS      1
# 5                    CHILE--JALAPENO 10#                 CS      1
# 6                    AVOCADO--#2 48CT-BR                 CS      1
# 7                   PEPPER--GREEN FX *L*                 CS      1
# 8         FRIES--3/8"CUT COATED ZTF 6/6#                 CS      1
# 9                CARROT--SHREDDED 5#--BG                 BA      1
# 10        CELERY--STICK 4" 5#--BG BRINKE                 BA      1
# 11                 PEPPER--RED 5#--SPLIT                 PK      1
# 12                TOMATO--LOOSE 5X5 BULK                 CS      1
# 13              CILANTRO--CLEANED 1#--BG                 LB      1
# 14                CILANTRO--CLEANED 4/1#                 CS      1
# 15                 TOMATO--SALSA 25# UBU                 CS      1
# 16        LETTUCE--ICEBERG CHPD 1X1 8/2#                 CS      1
# 17                   SPRING MIX--4/3# BR                 CS      1
# 18            SPINACH--CLIPPED 4/2.5#-BR                 CS      1
# 19                   AVOCADO--#2 48CT-BR                 CS      1
# 20             BROCCOLI--FLORETS 6/3# BR                 CS      1
# 21                 CUCUMBER--PICKLING BR                 CS      1
# 22            ONION--YELLOW JUMBO 50# BR                 CS      1
# 23            ASPARAGUS--STANDARD 11# BR                 CS      1
# 24        LETTUCE--ICEBERG SHRED 4/5# BR                 CS      1
# 25              TOMATO--GRAPE RED 10# BR                 CS      1
# 26                  PEPPER--GREEN FX *L*                 CS      1
# 27        FRIES--3/8"CUT COATED ZTF 6/6#                 CS      1
# 28               CARROT--SHREDDED 5#--BG                 BA      1
# 29             GARLIC--PEELED 5# CA ONLY                 BA      1
# ...                                  ...                ...    ...
# 495952      LETTUCE ROMAINE CHOP 8X2# BR                 CS      1
# 495953                ASPARAGUS STANDARD                 CS      1
# 495954                   CUCUMBERS HYDRO                 CS      1
# 495955              TOMATO CAFE #2 CT BR                 CS      1
# 495956       BROCCOLI FLORETS 6/3# CT BR                 CS      1
# 495957                 CELERY STICKS 5LB                 EA      1
# 495958      PINEAPPLE GOLD PREMIUM 5-9CT                 CS      1
# 495959         PEPPER JALAPENO GREEN 10#                 CS      1
# 495960            AVOCADO BR CT. 60CT #2                 CS      1
# 495961       WHOLLY HAND SCOOPED AVOCADO                 CS      1
# 495962          MUSHROOM SLICED 1/4" 10#                 CS      1
# 495963    COLESLAW FINE SHRED W/CARROT 5                 EA      1
# 495964     LETTUCE ICEBERG SHRED 4/5# CT                 CS      1
# 495965         ONION GREEN PENCIL 2# BAG                 EA      1
# 495966             SPRING MIX 4/3# CT BR                 CS      1
# 495967    LETTUCE ICEBERG CHOP CT 1" 8/2                 CS      1
# 495968              PEPPER GREEN CHOPPER                 CS      1
# 495969                     PEPPER RED CH                 CS      1
# 495970                   CUCUMBERS HYDRO                 CS      1
# 495971                   TOMATO 5X5 BULK                 CS      1
# 495972              TOMATO CAFE #2 CT BR                 CS      1
# 495973       BROCCOLI FLORETS 6/3# CT BR                 CS      1
# 495974    TOMATO GRAPE RED BULK 10# CT B                 CS      1
# 495975            AVOCADO BR CT. 60CT #2                 CS      1
# 495976       WHOLLY HAND SCOOPED AVOCADO                 CS      1
# 495977        ONION RED MEDIUM 25# CT BR                 CS      1
# 495978       CHEESE MOZZARELLA PEARL LOG                 CS      6
# 495979  CONTAINER,SLIM JIM,23 GAL,BLACK,                 EA      4
# 495980                           FREIGHT                 EA      0
# 495981                  CUCUMBERS SELECT                 CS      1
#
#        DC_QTY_SIZE  DELIVERED_QUANTITY  DELIVERED_PRICE  UNIT_PRICE
# 0             88CT                 1.0            18.73       18.92
# 1             4/3#                 1.0            21.40       21.62
# 2             6/3#                 1.0            21.20       21.41
# 3              50#                 1.0            12.87       13.00
# 4             8/2#                 3.0            32.08       10.80
# 5              10#                 2.0            23.38       11.81
# 6             48CT                 1.0            38.91       39.30
# 7              22#                 1.0            19.67       19.87
# 8             6/6#                 4.0            70.29       17.75
# 9               5#                 1.0             6.89        6.96
# 10              5#                 1.0             7.03        7.10
# 11              5#                 1.0             9.02        9.11
# 12             25#                 1.0            16.33       16.50
# 13              1#                 5.0            24.35        4.92
# 14            4/1#                 2.0            27.09       13.68
# 15             25#                 5.0            60.39       12.20
# 16            8/2#                 5.0            53.46       10.80
# 17            4/3#                 2.0            42.81       21.62
# 18          4/2.5#                 1.0            13.50       13.64
# 19            48CT                 6.0           233.44       39.30
# 20            6/3#                 3.0            63.59       21.41
# 21         1/2 BUS                 2.0            40.09       20.25
# 22             50#                 2.0            25.74       13.00
# 23             11#                 1.0            19.88       20.08
# 24            4/5#                 2.0            25.52       12.89
# 25             10#                 1.0            15.59       15.75
# 26             22#                 1.0            19.67       19.87
# 27            6/6#                12.0           210.87       17.75
# 28              5#                 1.0             6.89        6.96
# 29              5#                 1.0            14.71       14.86
# ...            ...                 ...              ...         ...
# 495952        8/2#                 1.0            18.83       18.83
# 495953         11#                 1.0            34.07       34.07
# 495954        12CT                 1.0            17.87       17.87
# 495955         25#                 4.0            80.00       20.00
# 495956        6/3#                 2.0            50.54       25.27
# 495957          5#                 2.0            15.24        7.62
# 495958     5/6/7CT                 1.0            16.62       16.62
# 495959         10#                 1.0            24.23       24.23
# 495960        60CT                 3.0            92.10       30.70
# 495961       8/2LB                 2.0            81.70       40.85
# 495962         10#                 1.0            19.40       19.40
# 495963          5#                 1.0             6.04        6.04
# 495964        4/5#                 1.0            13.80       13.80
# 495965      2# BAG                 2.0            15.12        7.56
# 495966        4/3#                 1.0            23.58       23.58
# 495967       8/2LB                 2.0            44.64       22.32
# 495968        CASE                 1.0            20.89       20.89
# 495969        CASE                 1.0            26.80       26.80
# 495970        12CT                 1.0            17.87       17.87
# 495971         25#                 1.0            20.15       20.15
# 495972         25#                 3.0            48.00       16.00
# 495973        6/3#                 1.0            25.27       25.27
# 495974         10#                 1.0            14.15       14.15
# 495975        60CT                 1.0            28.70       28.70
# 495976       8/2LB                 1.0            40.85       40.85
# 495977         25#                 1.0            13.47       13.47
# 495978      1.75LB                36.0          1381.32       38.37
# 495979          CS                22.0           506.62       23.03
# 495980          CS                 1.0             0.00        0.00
# 495981        CASE                 1.0            23.37       23.37
#
# [495982 rows x 13 columns]

# %%
#!/usr/bin/env python
# coding: utf-8

# In[4]:


# ANOMALIES:
# df[df['DELIVERED_PRICE'] == min(df['DELIVERED_PRICE'])]
import pandas as pd
from keras.utils import to_categorical
import numpy as np

dict_swap = {'GFS_CAN_EDM': 'GFS', 'GFS_CAN_CAL':'GFS', 'MAINES_1-BRINKER': 'MAINES', 'MAINES_2-BRINKER': 'MAINES'}
orgz = {'FRESHPOINT': 0, 'MAINES': 1, 'SYSCO':2, 'MBM':3, 'WASSER':4, 'GFS':5, 'YHATA':6, 'FSA_SSA':7, 'SIGNATURE':8}

def swap_orgs(row):
    if row['GROUPED_ORG'] in dict_swap:
        return dict_swap[row['GROUPED_ORG']]
    else:
        return row['GROUPED_ORG']
    
def swap_accs(row):
    if 'CHILI\'S' in row['GROUPED_ACC']:
        return 0  
    elif 'CHI' in row['GROUPED_ACC']:
        return 0 
    elif 'MAGGIANO' in row['GROUPED_ACC']: 
        return 1 
    elif 'INTL' in row['GROUPED_ACC']:
        return 2 
    else:
        return 3 
    
def swap_orgs_final(row):
    return orgz[row['finals']]


from dateutil import parser
def date_to_day_num(val):
    text_day = parser.parse(val['TRANSACTION_DATE']).strftime('%A')
    if text_day == 'Monday':
        return 0
    elif text_day == 'Tuesday':
        return 1
    elif text_day == 'Wednesday':
        return 2
    elif text_day == 'Thursday':
        return 3
    elif text_day == 'Friday':
        return 4
    elif text_day == 'Saturday':
        return 5
    elif text_day == 'Sunday':
        return 6

import re 
def strip_extra_description(row):
    no_dash = row['PROC_NAME'].replace('-',' ')
    temp = re.split(r'[0-9]', no_dash)[0]
    less = temp.strip('/#')
    even_less = re.split(r'\*l*', less)[0]
    return even_less

# top15 = {}
# numerical_vals = {}
def take_first(data, top15, numerical_vals):
    for desc in data['PROC_NAME'].split(' '):
        if desc in list(top15['Name'].values):
            return numerical_vals[desc]
    return 25

def clean_data(df):
    df_dropped = df

    upper_limit = df_dropped['UNIT_PRICE'].quantile(0.999)
    df_dropped = df_dropped[(df_dropped['UNIT_PRICE'] < upper_limit) & (df_dropped['UNIT_PRICE'] > 0)] # drop outliers

    upper_limit = df_dropped['DELIVERED_PRICE'].quantile(0.999)
    df_dropped = df_dropped[(df_dropped['DELIVERED_PRICE'] < upper_limit) & (df_dropped['DELIVERED_PRICE'] > 0)]

    upper_limit = df_dropped['DELIVERED_QUANTITY'].quantile(0.999)
    df_dropped = df_dropped[(df_dropped['DELIVERED_QUANTITY'] < upper_limit) & (df_dropped['DELIVERED_QUANTITY'] > 0)]

    dropped_vals = df_dropped 

    # Creates Normalized Attributes
    dropped_vals['NORM_UNI_PRICE'] = (2 * ((dropped_vals['UNIT_PRICE'] - min(dropped_vals['UNIT_PRICE'])) / (max(dropped_vals['UNIT_PRICE']) - min(dropped_vals['UNIT_PRICE'])))) - 1

    dropped_vals['NORM_DEL_PRICE'] = (2 * ((dropped_vals['DELIVERED_PRICE'] - min(dropped_vals['DELIVERED_PRICE'])) / (max(dropped_vals['DELIVERED_PRICE']) - min(dropped_vals['DELIVERED_PRICE'])))) - 1

    dropped_vals['NORM_DEL_QUANT'] = (2 * ((dropped_vals['DELIVERED_QUANTITY'] - min(dropped_vals['DELIVERED_QUANTITY'])) / (max(dropped_vals['DELIVERED_QUANTITY']) - min(dropped_vals['DELIVERED_QUANTITY'])))) - 1

    # Grouping Orgs
    dropped_vals['GROUPED_ORG'] = dropped_vals['ORGANIZATION NUMBER'].str.strip('0123456789-_')
    dropped_vals['finals'] = dropped_vals.apply(swap_orgs, axis=1)
    dropped_vals['fin_org_num'] = dropped_vals.apply(swap_orgs_final, axis=1)
    onehotting5 = to_categorical(dropped_vals['fin_org_num'].values[:,np.newaxis]).tolist()

    
    # Group Account_Name
    dropped_vals['GROUPED_ACC'] = dropped_vals['ACCOUNT_NAME'].str.strip('#0123456789-_/')
    dropped_vals['final_acc'] = dropped_vals.apply(swap_accs, axis=1)
    beans5 = to_categorical(dropped_vals['final_acc'].values[:,np.newaxis]).tolist()
    
    
    # Date Data
    dropped_vals['DAY_VAL'] = dropped_vals.apply(date_to_day_num, axis=1)
    hot_date = to_categorical(dropped_vals['DAY_VAL'].values[:,np.newaxis]).tolist()
    
    # Making NumPy Array
    norm_array = dropped_vals[['NORM_UNI_PRICE','NORM_DEL_PRICE','NORM_DEL_QUANT']]
    stacked_acc = np.hstack((norm_array.values, beans5))
    together = np.hstack((stacked_acc, onehotting5))
    with_date = np.hstack((together, hot_date))
    
    # Save np array of attributes up to the date
    np.save('with_date.npy', with_date)

    
    ## ITEM DESCRIPTION WORK
    dropped_vals['PROC_NAME'] = dropped_vals['DC_PROD_NAME'].str.lower()
    dropped_vals['PROC_NAME'] = dropped_vals.apply(strip_extra_description, axis=1)


    # Current model does not use the product's name, hence the early return statement. 
    # return

    # Turn Product Name into a Categorical Value using Bag of Words Model
    itemCount = {}
    for value in list(dropped_vals['PROC_NAME']):
        for desc in value.split(' '):
            if desc in itemCount:
                itemCount[desc] += 1
            else:
                itemCount[desc] = 1
                
    
    # Drop word values that are closely linked to other words
    # EX: 'Spring' and 'Mix' always appear together, so we drop 'Spring' in exchange for more meaningful words
    itemCount.pop('', None)
    itemCount.pop('br', None)
    itemCount.pop('ct', None)
    itemCount.pop('chpd', None)
    itemCount.pop('chop', None)
    itemCount.pop('fx', None)
    itemCount.pop('ct.', None)
    itemCount.pop('cafe', None)
    itemCount.pop('red', None)
    itemCount.pop('yellow', None)
    itemCount.pop('green', None)
    itemCount.pop('gold', None)
    itemCount.pop('spring',None)
    itemCount.pop('iceberg', None)
    itemCount.pop('florets', None)
    itemCount.pop('loose', None)
    itemCount.pop('scooped', None)
    itemCount.pop('iceless', None)

    
    foodDf = pd.DataFrame({'Name':list(itemCount.keys()), 'Count':list(itemCount.values())})
    top15 = foodDf.sort_values(ascending=False, by='Count').iloc[:25]

    numerical_vals = dict((k, v) for (k,v) in zip(top15['Name'].values, np.arange(0,25)))

    dropped_vals['MIN_NAME'] = dropped_vals.apply(take_first, axis=1, args=(top15, numerical_vals))

    # One-hot encode the categorical representation of product names
    hot_names = to_categorical(dropped_vals['MIN_NAME'].values[:,np.newaxis]).tolist()

    # Create new numpy file with encoding of product name
    bucket_names = np.hstack((with_date, hot_names))
    
    np.save('hot_names.npy', bucket_names)
    return dropped_vals

# %%
finalDf = clean_data(df)
finalDf
# Out:
#        ORGANIZATION NUMBER           ACCOUNT_NAME  PACKAGE_ID INVOICE_NUM  \
# 0           FRESHPOINT_158   BRINKER-CHILI'S #075    36316567     1845456
# 1           FRESHPOINT_158   BRINKER-CHILI'S #075    36316567     1845456
# 2           FRESHPOINT_158   BRINKER-CHILI'S #075    36316567     1845456
# 3           FRESHPOINT_158   BRINKER-CHILI'S #075    36316567     1845456
# 4           FRESHPOINT_158   BRINKER-CHILI'S #075    36316567     1845456
# 5           FRESHPOINT_158   BRINKER-CHILI'S #075    36316567     1845456
# 6           FRESHPOINT_158   BRINKER-CHILI'S #075    36316567     1845456
# 7           FRESHPOINT_158   BRINKER-CHILI'S #075    36316567     1845456
# 8           FRESHPOINT_158   BRINKER-CHILI'S #075    36316567     1845456
# 9           FRESHPOINT_158   BRINKER-CHILI'S #075    36316567     1845456
# 10          FRESHPOINT_158   BRINKER-CHILI'S #075    36316567     1845456
# 11          FRESHPOINT_158   BRINKER-CHILI'S #075    36316567     1845456
# 12          FRESHPOINT_158   BRINKER-CHILI'S #075    36316567     1845456
# 13          FRESHPOINT_158   BRINKER-CHILI'S #075    36316567     1845456
# 14          FRESHPOINT_158   BRINKER-CHILI'S #075    36340569     1846684
# 15          FRESHPOINT_158   BRINKER-CHILI'S #075    36340569     1846684
# 16          FRESHPOINT_158   BRINKER-CHILI'S #075    36340569     1846684
# 17          FRESHPOINT_158   BRINKER-CHILI'S #075    36340569     1846684
# 18          FRESHPOINT_158   BRINKER-CHILI'S #075    36340569     1846684
# 19          FRESHPOINT_158   BRINKER-CHILI'S #075    36340569     1846684
# 20          FRESHPOINT_158   BRINKER-CHILI'S #075    36340569     1846684
# 21          FRESHPOINT_158   BRINKER-CHILI'S #075    36340569     1846684
# 22          FRESHPOINT_158   BRINKER-CHILI'S #075    36340569     1846684
# 23          FRESHPOINT_158   BRINKER-CHILI'S #075    36340569     1846684
# 24          FRESHPOINT_158   BRINKER-CHILI'S #075    36340569     1846684
# 25          FRESHPOINT_158   BRINKER-CHILI'S #075    36340569     1846684
# 26          FRESHPOINT_158   BRINKER-CHILI'S #075    36340569     1846684
# 27          FRESHPOINT_158   BRINKER-CHILI'S #075    36340569     1846684
# 28          FRESHPOINT_158   BRINKER-CHILI'S #075    36340569     1846684
# 29          FRESHPOINT_158   BRINKER-CHILI'S #075    36340569     1846684
# ...                    ...                    ...         ...         ...
# 495949      FRESHPOINT_108  BRINKER CHILI'S #1309    44063577     4124603
# 495950      FRESHPOINT_108  BRINKER CHILI'S #1309    44063577     4124603
# 495951      FRESHPOINT_108  BRINKER CHILI'S #1309    44063577     4124603
# 495952      FRESHPOINT_108  BRINKER CHILI'S #1309    44063577     4124603
# 495953      FRESHPOINT_108  BRINKER CHILI'S #1309    44063577     4124603
# 495954      FRESHPOINT_108  BRINKER CHILI'S #1309    44063577     4124603
# 495955      FRESHPOINT_108  BRINKER CHILI'S #1309    44063577     4124603
# 495956      FRESHPOINT_108  BRINKER CHILI'S #1309    44063577     4124603
# 495957      FRESHPOINT_108  BRINKER CHILI'S #1309    44063577     4124603
# 495958      FRESHPOINT_108  BRINKER CHILI'S #1309    44063577     4124603
# 495959      FRESHPOINT_108  BRINKER CHILI'S #1309    44063577     4124603
# 495960      FRESHPOINT_108  BRINKER CHILI'S #1309    44063577     4124603
# 495961      FRESHPOINT_108  BRINKER CHILI'S #1309    44063577     4124603
# 495962      FRESHPOINT_108  BRINKER CHILI'S #1309    44063577     4124603
# 495963      FRESHPOINT_108  BRINKER CHILI'S #1309    44084501     4125152
# 495964      FRESHPOINT_108  BRINKER CHILI'S #1309    44084501     4125152
# 495965      FRESHPOINT_108  BRINKER CHILI'S #1309    44084501     4125152
# 495966      FRESHPOINT_108  BRINKER CHILI'S #1309    44084501     4125152
# 495967      FRESHPOINT_108  BRINKER CHILI'S #1309    44084501     4125152
# 495968      FRESHPOINT_108  BRINKER CHILI'S #1309    44084501     4125152
# 495969      FRESHPOINT_108  BRINKER CHILI'S #1309    44084501     4125152
# 495970      FRESHPOINT_108  BRINKER CHILI'S #1309    44084501     4125152
# 495971      FRESHPOINT_108  BRINKER CHILI'S #1309    44084501     4125152
# 495972      FRESHPOINT_108  BRINKER CHILI'S #1309    44084501     4125152
# 495973      FRESHPOINT_108  BRINKER CHILI'S #1309    44084501     4125152
# 495974      FRESHPOINT_108  BRINKER CHILI'S #1309    44084501     4125152
# 495975      FRESHPOINT_108  BRINKER CHILI'S #1309    44084501     4125152
# 495976      FRESHPOINT_108  BRINKER CHILI'S #1309    44084501     4125152
# 495977      FRESHPOINT_108  BRINKER CHILI'S #1309    44084501     4125152
# 495981      FRESHPOINT_108   BRINKER CHILI'S #455    43983340     4120812
#
#        TRANSACTION_DATE DC_PROD_NUM                    DC_PROD_NAME  \
# 0             01-MAR-17      100047                 ORANGES--88CT *
# 1             01-MAR-17      101217             SPRING MIX--4/3# BR
# 2             01-MAR-17      101575       BROCCOLI--FLORETS 6/3# BR
# 3             01-MAR-17      101699      ONION--YELLOW JUMBO 50# BR
# 4             01-MAR-17      101216  LETTUCE--ICEBERG CHPD 1X1 8/2#
# 5             01-MAR-17      100821             CHILE--JALAPENO 10#
# 6             01-MAR-17      101320             AVOCADO--#2 48CT-BR
# 7             01-MAR-17      101982            PEPPER--GREEN FX *L*
# 8             01-MAR-17      430070  FRIES--3/8"CUT COATED ZTF 6/6#
# 9             01-MAR-17      100218         CARROT--SHREDDED 5#--BG
# 10            01-MAR-17      101617  CELERY--STICK 4" 5#--BG BRINKE
# 11            01-MAR-17      850122           PEPPER--RED 5#--SPLIT
# 12            01-MAR-17      870024          TOMATO--LOOSE 5X5 BULK
# 13            01-MAR-17      100067        CILANTRO--CLEANED 1#--BG
# 14            03-MAR-17      100067          CILANTRO--CLEANED 4/1#
# 15            03-MAR-17      100294           TOMATO--SALSA 25# UBU
# 16            03-MAR-17      101216  LETTUCE--ICEBERG CHPD 1X1 8/2#
# 17            03-MAR-17      101217             SPRING MIX--4/3# BR
# 18            03-MAR-17      101306      SPINACH--CLIPPED 4/2.5#-BR
# 19            03-MAR-17      101320             AVOCADO--#2 48CT-BR
# 20            03-MAR-17      101575       BROCCOLI--FLORETS 6/3# BR
# 21            03-MAR-17      101664           CUCUMBER--PICKLING BR
# 22            03-MAR-17      101699      ONION--YELLOW JUMBO 50# BR
# 23            03-MAR-17      101724      ASPARAGUS--STANDARD 11# BR
# 24            03-MAR-17      101786  LETTUCE--ICEBERG SHRED 4/5# BR
# 25            03-MAR-17      101802        TOMATO--GRAPE RED 10# BR
# 26            03-MAR-17      101982            PEPPER--GREEN FX *L*
# 27            03-MAR-17      430070  FRIES--3/8"CUT COATED ZTF 6/6#
# 28            03-MAR-17      100218         CARROT--SHREDDED 5#--BG
# 29            03-MAR-17      100911       GARLIC--PEELED 5# CA ONLY
# ...                 ...         ...                             ...
# 495949        26-JAN-19      400421         SPINACH FLAT LEAF CT BR
# 495950        26-JAN-19      490042          CILANTRO WASHED 1# BAG
# 495951        26-JAN-19      590192  LETTUCE ICEBERG CHOP CT 1" 8/2
# 495952        26-JAN-19      400108    LETTUCE ROMAINE CHOP 8X2# BR
# 495953        26-JAN-19      400030              ASPARAGUS STANDARD
# 495954        26-JAN-19      400270                 CUCUMBERS HYDRO
# 495955        26-JAN-19      401131            TOMATO CAFE #2 CT BR
# 495956        26-JAN-19      505002     BROCCOLI FLORETS 6/3# CT BR
# 495957        26-JAN-19      514034               CELERY STICKS 5LB
# 495958        26-JAN-19      100511    PINEAPPLE GOLD PREMIUM 5-9CT
# 495959        26-JAN-19      400853       PEPPER JALAPENO GREEN 10#
# 495960        26-JAN-19      101304          AVOCADO BR CT. 60CT #2
# 495961        26-JAN-19      120306     WHOLLY HAND SCOOPED AVOCADO
# 495962        26-JAN-19      400461        MUSHROOM SLICED 1/4" 10#
# 495963        28-JAN-19      500405  COLESLAW FINE SHRED W/CARROT 5
# 495964        28-JAN-19      505001   LETTUCE ICEBERG SHRED 4/5# CT
# 495965        28-JAN-19      400530       ONION GREEN PENCIL 2# BAG
# 495966        28-JAN-19      505003           SPRING MIX 4/3# CT BR
# 495967        28-JAN-19      590192  LETTUCE ICEBERG CHOP CT 1" 8/2
# 495968        28-JAN-19      400621            PEPPER GREEN CHOPPER
# 495969        28-JAN-19      400650                   PEPPER RED CH
# 495970        28-JAN-19      400270                 CUCUMBERS HYDRO
# 495971        28-JAN-19      401062                 TOMATO 5X5 BULK
# 495972        28-JAN-19      401131            TOMATO CAFE #2 CT BR
# 495973        28-JAN-19      505002     BROCCOLI FLORETS 6/3# CT BR
# 495974        28-JAN-19      401194  TOMATO GRAPE RED BULK 10# CT B
# 495975        28-JAN-19      101304          AVOCADO BR CT. 60CT #2
# 495976        28-JAN-19      120306     WHOLLY HAND SCOOPED AVOCADO
# 495977        28-JAN-19      400569      ONION RED MEDIUM 25# CT BR
# 495981        18-JAN-19      400280                CUCUMBERS SELECT
#
#        DC_UNIT_OF_MEASURE DC_QTY DC_QTY_SIZE  ...  NORM_DEL_PRICE  \
# 0                      CS      1        88CT  ...       -0.885436
# 1                      CS      1        4/3#  ...       -0.869087
# 2                      CS      1        6/3#  ...       -0.870312
# 3                      CS      1         50#  ...       -0.921318
# 4                      CS      1        8/2#  ...       -0.803692
# 5                      CS      1         10#  ...       -0.856964
# 6                      CS      1        48CT  ...       -0.761871
# 7                      CS      1         22#  ...       -0.879680
# 8                      CS      1        6/6#  ...       -0.569727
# 9                      BA      1          5#  ...       -0.957934
# 10                     BA      1          5#  ...       -0.957077
# 11                     PK      1          5#  ...       -0.944892
# 12                     CS      1         25#  ...       -0.900132
# 13                     LB      1          1#  ...       -0.851024
# 14                     CS      1        4/1#  ...       -0.834247
# 15                     CS      1         25#  ...       -0.630346
# 16                     CS      1        8/2#  ...       -0.672780
# 17                     CS      1        4/3#  ...       -0.737991
# 18                     CS      1      4/2.5#  ...       -0.917460
# 19                     CS      1        48CT  ...        0.429262
# 20                     CS      1        6/3#  ...       -0.610752
# 21                     CS      1     1/2 BUS  ...       -0.754646
# 22                     CS      1         50#  ...       -0.842513
# 23                     CS      1         11#  ...       -0.878395
# 24                     CS      1        4/5#  ...       -0.843860
# 25                     CS      1         10#  ...       -0.904663
# 26                     CS      1         22#  ...       -0.879680
# 27                     CS      1        6/6#  ...        0.291063
# 28                     BA      1          5#  ...       -0.957934
# 29                     BA      1          5#  ...       -0.910051
# ...                   ...    ...         ...  ...             ...
# 495949                 CS      1         10#  ...       -0.904785
# 495950                 EA      1       POUND  ...       -0.932646
# 495951                 CS      1       8/2LB  ...       -0.726786
# 495952                 CS      1        8/2#  ...       -0.884824
# 495953                 CS      1         11#  ...       -0.791507
# 495954                 CS      1        12CT  ...       -0.890702
# 495955                 CS      1         25#  ...       -0.510272
# 495956                 CS      1        6/3#  ...       -0.690659
# 495957                 EA      1          5#  ...       -0.906806
# 495958                 CS      1     5/6/7CT  ...       -0.898356
# 495959                 CS      1         10#  ...       -0.851759
# 495960                 CS      1        60CT  ...       -0.436182
# 495961                 CS      1       8/2LB  ...       -0.499862
# 495962                 CS      1         10#  ...       -0.881334
# 495963                 EA      1          5#  ...       -0.963139
# 495964                 CS      1        4/5#  ...       -0.915623
# 495965                 EA      1      2# BAG  ...       -0.907541
# 495966                 CS      1        4/3#  ...       -0.855739
# 495967                 CS      1       8/2LB  ...       -0.726786
# 495968                 CS      1        CASE  ...       -0.872210
# 495969                 CS      1        CASE  ...       -0.836022
# 495970                 CS      1        12CT  ...       -0.890702
# 495971                 CS      1         25#  ...       -0.876741
# 495972                 CS      1         25#  ...       -0.706212
# 495973                 CS      1        6/3#  ...       -0.845391
# 495974                 CS      1         10#  ...       -0.913480
# 495975                 CS      1        60CT  ...       -0.824388
# 495976                 CS      1       8/2LB  ...       -0.749992
# 495977                 CS      1         25#  ...       -0.917644
# 495981                 CS      1        CASE  ...       -0.857025
#
#         NORM_DEL_QUANT  GROUPED_ORG      finals  fin_org_num  \
# 0            -1.000000   FRESHPOINT  FRESHPOINT            0
# 1            -1.000000   FRESHPOINT  FRESHPOINT            0
# 2            -1.000000   FRESHPOINT  FRESHPOINT            0
# 3            -1.000000   FRESHPOINT  FRESHPOINT            0
# 4            -0.692308   FRESHPOINT  FRESHPOINT            0
# 5            -0.846154   FRESHPOINT  FRESHPOINT            0
# 6            -1.000000   FRESHPOINT  FRESHPOINT            0
# 7            -1.000000   FRESHPOINT  FRESHPOINT            0
# 8            -0.538462   FRESHPOINT  FRESHPOINT            0
# 9            -1.000000   FRESHPOINT  FRESHPOINT            0
# 10           -1.000000   FRESHPOINT  FRESHPOINT            0
# 11           -1.000000   FRESHPOINT  FRESHPOINT            0
# 12           -1.000000   FRESHPOINT  FRESHPOINT            0
# 13           -0.384615   FRESHPOINT  FRESHPOINT            0
# 14           -0.846154   FRESHPOINT  FRESHPOINT            0
# 15           -0.384615   FRESHPOINT  FRESHPOINT            0
# 16           -0.384615   FRESHPOINT  FRESHPOINT            0
# 17           -0.846154   FRESHPOINT  FRESHPOINT            0
# 18           -1.000000   FRESHPOINT  FRESHPOINT            0
# 19           -0.230769   FRESHPOINT  FRESHPOINT            0
# 20           -0.692308   FRESHPOINT  FRESHPOINT            0
# 21           -0.846154   FRESHPOINT  FRESHPOINT            0
# 22           -0.846154   FRESHPOINT  FRESHPOINT            0
# 23           -1.000000   FRESHPOINT  FRESHPOINT            0
# 24           -0.846154   FRESHPOINT  FRESHPOINT            0
# 25           -1.000000   FRESHPOINT  FRESHPOINT            0
# 26           -1.000000   FRESHPOINT  FRESHPOINT            0
# 27            0.692308   FRESHPOINT  FRESHPOINT            0
# 28           -1.000000   FRESHPOINT  FRESHPOINT            0
# 29           -1.000000   FRESHPOINT  FRESHPOINT            0
# ...                ...          ...         ...          ...
# 495949       -1.000000   FRESHPOINT  FRESHPOINT            0
# 495950       -0.846154   FRESHPOINT  FRESHPOINT            0
# 495951       -0.846154   FRESHPOINT  FRESHPOINT            0
# 495952       -1.000000   FRESHPOINT  FRESHPOINT            0
# 495953       -1.000000   FRESHPOINT  FRESHPOINT            0
# 495954       -1.000000   FRESHPOINT  FRESHPOINT            0
# 495955       -0.538462   FRESHPOINT  FRESHPOINT            0
# 495956       -0.846154   FRESHPOINT  FRESHPOINT            0
# 495957       -0.846154   FRESHPOINT  FRESHPOINT            0
# 495958       -1.000000   FRESHPOINT  FRESHPOINT            0
# 495959       -1.000000   FRESHPOINT  FRESHPOINT            0
# 495960       -0.692308   FRESHPOINT  FRESHPOINT            0
# 495961       -0.846154   FRESHPOINT  FRESHPOINT            0
# 495962       -1.000000   FRESHPOINT  FRESHPOINT            0
# 495963       -1.000000   FRESHPOINT  FRESHPOINT            0
# 495964       -1.000000   FRESHPOINT  FRESHPOINT            0
# 495965       -0.846154   FRESHPOINT  FRESHPOINT            0
# 495966       -1.000000   FRESHPOINT  FRESHPOINT            0
# 495967       -0.846154   FRESHPOINT  FRESHPOINT            0
# 495968       -1.000000   FRESHPOINT  FRESHPOINT            0
# 495969       -1.000000   FRESHPOINT  FRESHPOINT            0
# 495970       -1.000000   FRESHPOINT  FRESHPOINT            0
# 495971       -1.000000   FRESHPOINT  FRESHPOINT            0
# 495972       -0.692308   FRESHPOINT  FRESHPOINT            0
# 495973       -1.000000   FRESHPOINT  FRESHPOINT            0
# 495974       -1.000000   FRESHPOINT  FRESHPOINT            0
# 495975       -1.000000   FRESHPOINT  FRESHPOINT            0
# 495976       -1.000000   FRESHPOINT  FRESHPOINT            0
# 495977       -1.000000   FRESHPOINT  FRESHPOINT            0
# 495981       -1.000000   FRESHPOINT  FRESHPOINT            0
#
#              GROUPED_ACC final_acc DAY_VAL                      PROC_NAME  \
# 0       BRINKER-CHILI'S          0       2                      oranges
# 1       BRINKER-CHILI'S          0       2                   spring mix
# 2       BRINKER-CHILI'S          0       2             broccoli  florets
# 3       BRINKER-CHILI'S          0       2           onion  yellow jumbo
# 4       BRINKER-CHILI'S          0       2         lettuce  iceberg chpd
# 5       BRINKER-CHILI'S          0       2               chile  jalapeno
# 6       BRINKER-CHILI'S          0       2                      avocado
# 7       BRINKER-CHILI'S          0       2              pepper  green fx
# 8       BRINKER-CHILI'S          0       2                        fries
# 9       BRINKER-CHILI'S          0       2              carrot  shredded
# 10      BRINKER-CHILI'S          0       2                 celery  stick
# 11      BRINKER-CHILI'S          0       2                   pepper  red
# 12      BRINKER-CHILI'S          0       2                 tomato  loose
# 13      BRINKER-CHILI'S          0       2             cilantro  cleaned
# 14      BRINKER-CHILI'S          0       4             cilantro  cleaned
# 15      BRINKER-CHILI'S          0       4                 tomato  salsa
# 16      BRINKER-CHILI'S          0       4         lettuce  iceberg chpd
# 17      BRINKER-CHILI'S          0       4                   spring mix
# 18      BRINKER-CHILI'S          0       4              spinach  clipped
# 19      BRINKER-CHILI'S          0       4                      avocado
# 20      BRINKER-CHILI'S          0       4             broccoli  florets
# 21      BRINKER-CHILI'S          0       4          cucumber  pickling br
# 22      BRINKER-CHILI'S          0       4           onion  yellow jumbo
# 23      BRINKER-CHILI'S          0       4           asparagus  standard
# 24      BRINKER-CHILI'S          0       4        lettuce  iceberg shred
# 25      BRINKER-CHILI'S          0       4             tomato  grape red
# 26      BRINKER-CHILI'S          0       4              pepper  green fx
# 27      BRINKER-CHILI'S          0       4                        fries
# 28      BRINKER-CHILI'S          0       4              carrot  shredded
# 29      BRINKER-CHILI'S          0       4                garlic  peeled
# ...                  ...       ...     ...                            ...
# 495949  BRINKER CHILI'S          0       5        spinach flat leaf ct br
# 495950  BRINKER CHILI'S          0       5               cilantro washed
# 495951  BRINKER CHILI'S          0       5       lettuce iceberg chop ct
# 495952  BRINKER CHILI'S          0       5          lettuce romaine chop
# 495953  BRINKER CHILI'S          0       5             asparagus standard
# 495954  BRINKER CHILI'S          0       5                cucumbers hydro
# 495955  BRINKER CHILI'S          0       5                   tomato cafe
# 495956  BRINKER CHILI'S          0       5              broccoli florets
# 495957  BRINKER CHILI'S          0       5                 celery sticks
# 495958  BRINKER CHILI'S          0       5        pineapple gold premium
# 495959  BRINKER CHILI'S          0       5         pepper jalapeno green
# 495960  BRINKER CHILI'S          0       5                avocado br ct.
# 495961  BRINKER CHILI'S          0       5    wholly hand scooped avocado
# 495962  BRINKER CHILI'S          0       5               mushroom sliced
# 495963  BRINKER CHILI'S          0       0  coleslaw fine shred w/carrot
# 495964  BRINKER CHILI'S          0       0         lettuce iceberg shred
# 495965  BRINKER CHILI'S          0       0            onion green pencil
# 495966  BRINKER CHILI'S          0       0                    spring mix
# 495967  BRINKER CHILI'S          0       0       lettuce iceberg chop ct
# 495968  BRINKER CHILI'S          0       0           pepper green chopper
# 495969  BRINKER CHILI'S          0       0                  pepper red ch
# 495970  BRINKER CHILI'S          0       0                cucumbers hydro
# 495971  BRINKER CHILI'S          0       0                        tomato
# 495972  BRINKER CHILI'S          0       0                   tomato cafe
# 495973  BRINKER CHILI'S          0       0              broccoli florets
# 495974  BRINKER CHILI'S          0       0         tomato grape red bulk
# 495975  BRINKER CHILI'S          0       0                avocado br ct.
# 495976  BRINKER CHILI'S          0       0    wholly hand scooped avocado
# 495977  BRINKER CHILI'S          0       0              onion red medium
# 495981  BRINKER CHILI'S          0       4               cucumbers select
#
#        MIN_NAME
# 0            25
# 1             6
# 2             5
# 3             2
# 4             1
# 5            23
# 6             4
# 7             3
# 8            13
# 9            25
# 10           15
# 11            3
# 12            0
# 13           10
# 14           10
# 15            0
# 16            1
# 17            6
# 18           19
# 19            4
# 20            5
# 21            8
# 22            2
# 23            9
# 24            1
# 25            0
# 26            3
# 27           13
# 28           25
# 29           25
# ...         ...
# 495949       19
# 495950       10
# 495951        1
# 495952        1
# 495953        9
# 495954       25
# 495955        0
# 495956        5
# 495957       15
# 495958       16
# 495959        3
# 495960        4
# 495961       21
# 495962       25
# 495963       12
# 495964        1
# 495965        2
# 495966        6
# 495967        1
# 495968        3
# 495969        3
# 495970       25
# 495971        0
# 495972        0
# 495973        5
# 495974        0
# 495975        4
# 495976       21
# 495977        2
# 495981       25
#
# [489896 rows x 24 columns]

# %%
top15
# Out:
# {}
