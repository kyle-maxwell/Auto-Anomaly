# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/kylemaxwell/Desktop/Anomaly_Data.csv")
# Out:
# /Users/kylemaxwell/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3018: DtypeWarning: Columns (3,5,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#        ORGANIZATION NUMBER                  ACCOUNT_NAME  PACKAGE_ID  \
# 0           FRESHPOINT_158          BRINKER-CHILI'S #075    36316567
# 1           FRESHPOINT_158          BRINKER-CHILI'S #075    36316567
# 2           FRESHPOINT_158          BRINKER-CHILI'S #075    36316567
# 3           FRESHPOINT_158          BRINKER-CHILI'S #075    36316567
# 4           FRESHPOINT_158          BRINKER-CHILI'S #075    36316567
# 5           FRESHPOINT_158          BRINKER-CHILI'S #075    36316567
# 6           FRESHPOINT_158          BRINKER-CHILI'S #075    36316567
# 7           FRESHPOINT_158          BRINKER-CHILI'S #075    36316567
# 8           FRESHPOINT_158          BRINKER-CHILI'S #075    36316567
# 9           FRESHPOINT_158          BRINKER-CHILI'S #075    36316567
# 10          FRESHPOINT_158          BRINKER-CHILI'S #075    36316567
# 11          FRESHPOINT_158          BRINKER-CHILI'S #075    36316567
# 12          FRESHPOINT_158          BRINKER-CHILI'S #075    36316567
# ...

# %%
df.describe()
# Out:
#          PACKAGE_ID  DELIVERED_QUANTITY  DELIVERED_PRICE     UNIT_PRICE
# count  4.959820e+05       495982.000000    495982.000000  495982.000000
# mean   4.019072e+07            2.172887        36.665287      20.255455
# std    2.294726e+06          118.497499      1108.955539     345.763758
# min    3.630792e+07         -697.500000    -18156.960000       0.000000
# 25%    3.812544e+07            1.000000        14.540000      12.890000
# 50%    4.018880e+07            1.000000        20.300000      17.490000
# 75%    4.222832e+07            2.000000        36.220000      22.420000
# max    4.409691e+07        33660.000000    341649.000000  241080.090000

# %%
df.columns
# Out:
# Index(['ORGANIZATION NUMBER', 'ACCOUNT_NAME', 'PACKAGE_ID', 'INVOICE_NUM',
#        'TRANSACTION_DATE', 'CENTER_PROD_NUM', 'CENTER_PROD_NAME',
#        'CENTER_UNIT_OF_MEASURE', 'DC_QTY', 'DC_QTY_SIZE', 'DELIVERED_QUANTITY',
#        'DELIVERED_PRICE', 'UNIT_PRICE'],
#       dtype='object')

# %%
df['ORGANIZATION NUMBER'].unique()
# Out:
# array(['FRESHPOINT_158', 'FRESHPOINT_108', 'MAINES_1-BRINKER',
#        'FRESHPOINT_107', 'SYSCO024', 'MBM35', 'WASSER_49', 'MBM2',
#        'SYSCO045', 'GFS_CAN_EDM', 'GFS_CAN_CAL', 'MAINES_2-BRINKER',
#        'SYSCO037', 'SYSCO010', 'YHATA_001', 'FSA_SSA_521', 'WASSER_28',
#        'WASSER_35', 'WASSER_42', 'SIGNATURE_001', 'GFS04', 'SYSCO011',
#        'WASSER_21', 'SYSCO059', 'SYSCO013', 'SYSCO006', 'SYSCO067'],
#       dtype=object)

# %%
df['ACCOUNT_NAME'].unique()
# Out:
# array(["BRINKER-CHILI'S #075", "BRINKER-CHILI'S #1384",
#        "BRINKER-CHILI'S STN CREST", "BRINKER-CHILI'S MCDONOUGH",
#        "BRINKER-CHILI'S #730", "BRINKER-CHILI'S #057",
#        "BRINKER-CHILI'S #1187", "BRINKER CHILI'S #987",
#        "BRINKER CHILI'S MT.ZION", "BRINKER-CHILI'S #956",
#        "BRINKER-CHILI'S #624", "BRINKER-CHILI'S #275",
#        "BRINKER-CHILI'S #742", "BRINKER CHI'S PERIMETER",
#        "BRINKER CHILI'S FLOWERY B", "BRINKER-CHILI'S #1066",
#        "BRINKER CHILI'S TOWN CTR.", "BRINKER-CHILI'S #881",
#        "BRINKER-CHILI'S #670", "BRINKER-CHILI'S #960",
#        'BRINKER INTERNATIONAL', "BRINKER/CHILI'S ROME",
#        "BRINKER-CHILI'S #501", "BRINKER-CHILI'S #1181",
#        "BRINKER-CHILI'S #1306", "BRINKER-CHILI'S #970",
#        "BRINKER-CHILI'S #891", "BRINKER CHI'S TOCO HILL",
#        "BRINKER-CHILI'S #507", "BRINKER CHI'S P'TREE CITY",
#        "BRINKER-CHILI'S HIRAM", "BRINKER/CHILI'S CUMMING",
# ...

# %%
for index in df.columns:
    print(index)
    print(df[index].describe())
    print()
# Out:
# ORGANIZATION NUMBER
# count             495982
# unique                27
# top       FRESHPOINT_158
# freq              299806
# Name: ORGANIZATION NUMBER, dtype: object
#
# ACCOUNT_NAME
# count                      495982
# unique                        130
# top       BRINKER-MAGGIANO'S #183
# freq                        15776
# Name: ACCOUNT_NAME, dtype: object
#
# PACKAGE_ID
# count    4.959820e+05
# mean     4.019072e+07
# std      2.294726e+06
# min      3.630792e+07
# 25%      3.812544e+07
# 50%      4.018880e+07
# 75%      4.222832e+07
# max      4.409691e+07
# Name: PACKAGE_ID, dtype: float64
#
# INVOICE_NUM
# count        495982
# unique        38872
# top       415697057
# freq            115
# Name: INVOICE_NUM, dtype: object
#
# TRANSACTION_DATE
# count        495982
# unique          623
# top       31-AUG-18
# freq           1974
# Name: TRANSACTION_DATE, dtype: object
#
# CENTER_PROD_NUM
# count     495982
# unique      1609
# top       101216
# freq       10466
# ...

# %%
df.apply(lambda x: x.describe())
# Out:
#        ORGANIZATION NUMBER             ACCOUNT_NAME    PACKAGE_ID INVOICE_NUM  \
# 25%                    NaN                      NaN  3.812544e+07         NaN
# 50%                    NaN                      NaN  4.018880e+07         NaN
# 75%                    NaN                      NaN  4.222832e+07         NaN
# count               495982                   495982  4.959820e+05      495982
# freq                299806                    15776           NaN         115
# max                    NaN                      NaN  4.409691e+07         NaN
# mean                   NaN                      NaN  4.019072e+07         NaN
# min                    NaN                      NaN  3.630792e+07         NaN
# std                    NaN                      NaN  2.294726e+06         NaN
# top         FRESHPOINT_158  BRINKER-MAGGIANO'S #183           NaN   415697057
# unique                  27                      130           NaN       38872
#
# ...
